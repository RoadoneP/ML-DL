# %% [markdown]
# <a href="https://colab.research.google.com/github/RoadoneP/Machine_learning/blob/main/Waste_classification/waste_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
from google.colab import files
files.upload()

# %%
ls -1ha kaggle.json
# Out:
# kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Permission Warning 이 일어나지 않도록 
# !chmod 600 ~/.kaggle/kaggle.json
# 본인이 참가한 모든 대회 보기 
# !kaggle competitions list

# %%
! kaggle datasets download -d techsash/waste-classification-data
# Out:
# Downloading waste-classification-data.zip to /content
# 100% 427M/427M [00:02<00:00, 240MB/s]
# 100% 427M/427M [00:02<00:00, 157MB/s]

# %%
# !unzip waste-classification-data.zip

# %% [markdown]
# # 라이브러리

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Activation, Dropout, Input
from keras.models import Model, load_model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D
from keras.layers.core import Flatten, Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.engine.topology import Layer
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from PIL import Image
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_files
import itertools
import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #데이터 불러오기 및 처리

# %%
Image.open('/content/dataset/DATASET/TEST/O/O_13191.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=194x259 at 0x7FEC4031CD30>

# %%
train_dir = '/content/dataset/DATASET/TRAIN'
test_dir = '/content/dataset/DATASET/TEST'

def load_dataset(path):
  data = load_files(path) # 경로에서 파일 탐색
  files = np.array(data['filenames']) #파일 가져오기
  targets = np.array(data['target'])

  target_labels = np.array(data['target_names'])

  return files,targets,target_labels

x_train, y_train, target_labels = load_dataset(train_dir)
x_test, y_test,_ = load_dataset(test_dir)
print(target_labels)
print(np.unique(y_train))
print('Training set size : ', x_train.shape[0])
print('Testing set size : ', x_test.shape[0])
# Out:
# ['O' 'R']
# [0 1]
# Training set size :  22564
# Testing set size :  2513

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 1)

# %%
print("x_train shape: ",x_train.shape[0])
print("y_train shape: ",y_train.shape[0])
print("x_val shape: ",x_val.shape[0])
print("y_val shape: ",y_val.shape[0])
print("x_test shape: ",x_test.shape[0])
print("y_test shape: ",y_test.shape[0])
# Out:
# x_train shape:  18051
# y_train shape:  18051
# x_val shape:  4513
# y_val shape:  4513
# x_test shape:  2513
# y_test shape:  2513

# %% [markdown]
# # jpg to numpy array

# %%
img = cv2.imread(x_train[0], cv2.IMREAD_COLOR)
res = cv2.resize(img,dsize=(64, 64), interpolation = cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.xlabel(y_train[0])
# Out:
# (64, 64, 3)
# Text(0.5, 0, '1')

# %%
def convert_image_to_array(files):
  width, height, channels = 64, 64, 3
  images_as_array = np.empty((files.shape[0],width, height, channels), dtype = np.uint8)
  for idx, file in enumerate(files):
    img = cv2.imread(file)
    #이미지의 크기가 다르므로 모든 이미지의 크기를 동일한 이미지 배열 모양으로 조정
    res = cv2.resize(img, dsize = (width,height), interpolation = cv2.INTER_CUBIC)
    images_as_array[idx] = res
  return images_as_array

x_train = np.array(convert_image_to_array(x_train))
print('Training set shape : ',x_train.shape)

x_val = np.array(convert_image_to_array(x_val))
print('Validation set shape : ',x_val.shape)

x_test = np.array(convert_image_to_array(x_test))
print('Test set shape : ',x_test.shape)
# Out:
# Training set shape :  (18051, 64, 64, 3)
# Validation set shape :  (4513, 64, 64, 3)
# Test set shape :  (2513, 64, 64, 3)

# %%
x_train = x_train.astype('float32')/255
x_val = x_val.astype('float32')/255
x_test = x_test.astype('float32')/255
y_train = y_train.reshape(y_train.shape[0],1)
y_test = y_test.reshape(y_test.shape[0],1)
y_val = y_val.reshape(y_val.shape[0],1)

# %%
plt.figure(figsize=(20,20))
classes = ['R','O']
for i in range(1,26):
  index = np.random.randint(x_train.shape[0])
  plt.subplot(5, 5, i)
  plt.imshow(np.squeeze(x_train[index]), cmap='cool')
  plt.title(classes[int(y_train[index])])
  plt.tight_layout()
plt.show()

# %% [markdown]
# #Image augment

# %%
datagen = ImageDataGenerator(
    featurewise_center=False, #데이터 세트에 대해 입력 평균을 0으로 설정
    samplewise_center=False, #각 샘플 평균을 0으로 설정
    featurewise_std_normalization=False, # 데이터 세트의 표준으로 입력을 나눕니다.
    samplewise_std_normalization=False,  # 각 입력을 표준으로 나눕니다.
    zca_whitening=False,
    rotation_range = 0, #이미지 무작위 회전
    zoom_range = 0.1, #이미지 무작위 줌
    width_shift_range=0.2, #이미지 가로 이동
    height_shift_range=0.2, #이미지 세로 이동
    horizontal_flip=True, #이미지 뒤집기
    vertical_flip=False  #이미지 뒤집기
)
datagen.fit(x_train)

# %% [markdown]
# #model

# %%
def build_model():
  model = Sequential()

  input = Input(shape=(64,64,3))
  output = Conv2D(32,kernel_size=(3, 3),kernel_initializer='he_normal', activation='relu')(input)
  output = Conv2D(32, kernel_size=(3, 3),activation='relu')(output)
  output = BatchNormalization()(output)
  output = MaxPooling2D(pool_size=(2, 2))(output)
  output = Dropout(0.2)(output)

  output = Conv2D(64, kernel_size=(3, 3),activation='relu')(output)
  output = Conv2D(64, kernel_size=(3, 3),activation='relu')(output)
  output = BatchNormalization()(output)
  output = MaxPooling2D(pool_size=(2, 2))(output)
  output = Dropout(0.2)(output)

  output = Conv2D(128, kernel_size=(3, 3),activation='relu')(output)
  output = Conv2D(128, kernel_size=(3, 3),activation='relu')(output)
  output = BatchNormalization()(output)
  output = MaxPooling2D(pool_size=(2, 2))(output)
  output = Dropout(0.3)(output)

  #output = Conv2D(256, kernel_size=(3, 3),activation='relu')(output)
  #output = Conv2D(256, kernel_size=(3, 3),activation='relu')(output)
  #output = BatchNormalization()(output)
  #output = MaxPooling2D(pool_size=(2, 2))(output)
  #output = Dropout(0.3)(output)

  output = Flatten()(output)
  #output = Dense(512, activation='relu')(output)
  output = Dense(256, activation='relu')(output)
  output = Dense(128, activation='relu')(output)
  output = Dropout(0.3)(output)
  output = Dense(1, activation='sigmoid')(output)

  model = Model(inputs=[input], outputs=output)

  model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['acc'])
  return model

model = build_model()
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 62, 62, 32)        896
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 60, 60, 32)        9248
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 60, 60, 32)        128
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 26, 26, 64)        36928
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 26, 26, 64)        256
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 11, 11, 128)       73856
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 9, 9, 128)         147584
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 9, 9, 128)         512
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 845,473
# Trainable params: 845,025
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# Epoch 훈련 반복 중에 가장 낮은 손실이 달성되면 모델을 저장.

# %%
checkpoint = ModelCheckpoint(filepath='cnn.hdf5', verbose= 1 , save_best_only= True)

# %% [markdown]
# 또한 Epoch 훈련 반복으로 손실이 감소하지 않는 경우 모델 훈련을 중지

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta= 0 , patience= 10, verbose= 1, restore_best_weights= True)

# %% [markdown]
# 개선이 보이지 않으면 학습률을 줄인다.

# %%
ReduceLR = ReduceLROnPlateau(patience=3, verbose=1)

# %%
callbacks = [earlystop, checkpoint, ReduceLR]

# %%
history = model.fit_generator(datagen.flow(x_train, y_train, batch_size= 32), epochs = 80, verbose=1,callbacks = callbacks,validation_data=(x_val,y_val))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/80
# 565/565 [==============================] - 23s 40ms/step - loss: 0.5591 - acc: 0.7550 - val_loss: 0.4311 - val_acc: 0.7908
#
# Epoch 00001: val_loss improved from inf to 0.43108, saving model to cnn.hdf5
# Epoch 2/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.4269 - acc: 0.8156 - val_loss: 0.4348 - val_acc: 0.8154
#
# Epoch 00002: val_loss did not improve from 0.43108
# Epoch 3/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.4074 - acc: 0.8297 - val_loss: 0.3847 - val_acc: 0.8495
#
# Epoch 00003: val_loss improved from 0.43108 to 0.38473, saving model to cnn.hdf5
# Epoch 4/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.3824 - acc: 0.8431 - val_loss: 0.3609 - val_acc: 0.8453
#
# Epoch 00004: val_loss improved from 0.38473 to 0.36094, saving model to cnn.hdf5
# Epoch 5/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.3585 - acc: 0.8580 - val_loss: 0.3223 - val_acc: 0.8690
#
# Epoch 00005: val_loss improved from 0.36094 to 0.32227, saving model to cnn.hdf5
# Epoch 6/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.3640 - acc: 0.8507 - val_loss: 0.5321 - val_acc: 0.7509
#
# Epoch 00006: val_loss did not improve from 0.32227
# Epoch 7/80
# 565/565 [==============================] - 22s 40ms/step - loss: 0.3475 - acc: 0.8633 - val_loss: 0.3964 - val_acc: 0.8252
#
# Epoch 00007: val_loss did not improve from 0.32227
# Epoch 8/80
# 565/565 [==============================] - 22s 40ms/step - loss: 0.3388 - acc: 0.8626 - val_loss: 0.3041 - val_acc: 0.8757
#
# Epoch 00008: val_loss improved from 0.32227 to 0.30409, saving model to cnn.hdf5
# Epoch 9/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.3326 - acc: 0.8649 - val_loss: 0.3735 - val_acc: 0.8272
#
# Epoch 00009: val_loss did not improve from 0.30409
# Epoch 10/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.3267 - acc: 0.8704 - val_loss: 0.3052 - val_acc: 0.8766
#
# Epoch 00010: val_loss did not improve from 0.30409
# Epoch 11/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.3208 - acc: 0.8725 - val_loss: 0.3284 - val_acc: 0.8637
#
# Epoch 00011: val_loss did not improve from 0.30409
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/80
# 565/565 [==============================] - 22s 40ms/step - loss: 0.2982 - acc: 0.8816 - val_loss: 0.2748 - val_acc: 0.8839
#
# Epoch 00012: val_loss improved from 0.30409 to 0.27477, saving model to cnn.hdf5
# Epoch 13/80
# 565/565 [==============================] - 22s 40ms/step - loss: 0.2874 - acc: 0.8885 - val_loss: 0.2630 - val_acc: 0.8941
#
# Epoch 00013: val_loss improved from 0.27477 to 0.26303, saving model to cnn.hdf5
# Epoch 14/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.2874 - acc: 0.8875 - val_loss: 0.2615 - val_acc: 0.8950
#
# Epoch 00014: val_loss improved from 0.26303 to 0.26154, saving model to cnn.hdf5
# Epoch 15/80
# 565/565 [==============================] - 22s 40ms/step - loss: 0.2645 - acc: 0.8963 - val_loss: 0.2585 - val_acc: 0.8974
#
# Epoch 00015: val_loss improved from 0.26154 to 0.25849, saving model to cnn.hdf5
# Epoch 16/80
# 565/565 [==============================] - 23s 40ms/step - loss: 0.2704 - acc: 0.8950 - val_loss: 0.2654 - val_acc: 0.8930
#
# Epoch 00016: val_loss did not improve from 0.25849
# Epoch 17/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.2679 - acc: 0.8962 - val_loss: 0.2609 - val_acc: 0.8965
#
# Epoch 00017: val_loss did not improve from 0.25849
# Epoch 18/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.2677 - acc: 0.8968 - val_loss: 0.2663 - val_acc: 0.8932
#
# Epoch 00018: val_loss did not improve from 0.25849
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 19/80
# 565/565 [==============================] - 22s 40ms/step - loss: 0.2588 - acc: 0.8965 - val_loss: 0.2600 - val_acc: 0.8950
#
# Epoch 00019: val_loss did not improve from 0.25849
# Epoch 20/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.2520 - acc: 0.9016 - val_loss: 0.2597 - val_acc: 0.8954
#
# Epoch 00020: val_loss did not improve from 0.25849
# Epoch 21/80
# 565/565 [==============================] - 23s 40ms/step - loss: 0.2716 - acc: 0.8932 - val_loss: 0.2586 - val_acc: 0.8956
#
# Epoch 00021: val_loss did not improve from 0.25849
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 22/80
# 565/565 [==============================] - 22s 40ms/step - loss: 0.2658 - acc: 0.8902 - val_loss: 0.2587 - val_acc: 0.8959
#
# Epoch 00022: val_loss did not improve from 0.25849
# Epoch 23/80
# 565/565 [==============================] - 22s 40ms/step - loss: 0.2670 - acc: 0.8942 - val_loss: 0.2587 - val_acc: 0.8954
#
# Epoch 00023: val_loss did not improve from 0.25849
# Epoch 24/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.2567 - acc: 0.8983 - val_loss: 0.2583 - val_acc: 0.8961
#
# Epoch 00024: val_loss improved from 0.25849 to 0.25831, saving model to cnn.hdf5
# Epoch 25/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.2552 - acc: 0.8990 - val_loss: 0.2576 - val_acc: 0.8961
#
# Epoch 00025: val_loss improved from 0.25831 to 0.25764, saving model to cnn.hdf5
# Epoch 26/80
# 565/565 [==============================] - 23s 40ms/step - loss: 0.2622 - acc: 0.8925 - val_loss: 0.2584 - val_acc: 0.8963
#
# Epoch 00026: val_loss did not improve from 0.25764
# Epoch 27/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.2708 - acc: 0.8919 - val_loss: 0.2590 - val_acc: 0.8950
#
# Epoch 00027: val_loss did not improve from 0.25764
# Epoch 28/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.2585 - acc: 0.8974 - val_loss: 0.2587 - val_acc: 0.8952
#
# Epoch 00028: val_loss did not improve from 0.25764
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 29/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.2570 - acc: 0.8964 - val_loss: 0.2586 - val_acc: 0.8959
#
# Epoch 00029: val_loss did not improve from 0.25764
# Epoch 30/80
# 565/565 [==============================] - 23s 40ms/step - loss: 0.2606 - acc: 0.8986 - val_loss: 0.2582 - val_acc: 0.8954
#
# Epoch 00030: val_loss did not improve from 0.25764
# Epoch 31/80
# 565/565 [==============================] - 22s 40ms/step - loss: 0.2648 - acc: 0.8946 - val_loss: 0.2583 - val_acc: 0.8959
#
# Epoch 00031: val_loss did not improve from 0.25764
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 32/80
# 565/565 [==============================] - 22s 40ms/step - loss: 0.2568 - acc: 0.8979 - val_loss: 0.2586 - val_acc: 0.8954
#
# Epoch 00032: val_loss did not improve from 0.25764
# Epoch 33/80
# 565/565 [==============================] - 22s 39ms/step - loss: 0.2601 - acc: 0.8965 - val_loss: 0.2593 - val_acc: 0.8952
#
# Epoch 00033: val_loss did not improve from 0.25764
# Epoch 34/80
# 565/565 [==============================] - 23s 40ms/step - loss: 0.2642 - acc: 0.9000 - val_loss: 0.2580 - val_acc: 0.8956
#
# Epoch 00034: val_loss did not improve from 0.25764
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 35/80
# 565/565 [==============================] - 23s 40ms/step - loss: 0.2595 - acc: 0.8967 - val_loss: 0.2588 - val_acc: 0.8961
# Restoring model weights from the end of the best epoch.
#
# Epoch 00035: val_loss did not improve from 0.25764
# Epoch 00035: early stopping

# %%
import pickle

pickle_out = open("Trained_cnn_history.pickle","wb")
pickle.dump(history.history, pickle_out)
pickle_out.close()

# %%
pickle_in = open("Trained_cnn_history.pickle","rb")
saved_history = pickle.load(pickle_in)
print(saved_history)
# Out:
